# %%
# %load_ext autoreload
# %autoreload 2
from utils import *
from preprocessing_new import preprocessing_new_2
import pickle
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.cm as cm
import numpy as np

#Training Data Set
for i in range(0, 6):
    print(i)
    path_of_the_directory='../data_split_resize/men/train/'+str(i)+'/'
    path_of_the_directory_result='../outputs/preprocessing/men/train/'+str(i)+'/'
    isExist = os.path.exists(path_of_the_directory_result)
    if not isExist:
        os.makedirs(path_of_the_directory_result)
        print("The new directory is created!")
    else:
        shutil.rmtree(path_of_the_directory_result, ignore_errors=False, onerror=None)
        os.mkdir(path_of_the_directory_result)
    ind=0
    max=2
    for filename in os.listdir(path_of_the_directory):
        if(ind>max):
            break
        ind=ind+1
        img = cv2.imread(path_of_the_directory+str(filename))
        if img is None:
            continue

        # Skin Masks
        # binary_hand=preprocessing_new_1(img)
        
        # region_filling=binary_hand=preprocessing_new_2(img)

        # OCR,binary_hand=preprocessing_OCR(img)
        # features_vector_train=np.vstack([features_vector_train,OCR])
        # Y_train=np.append(Y_train,i)

        # OCR,hand_mask,image_finger=preprocessing_new_3(img)
        # features_train=np.vstack([features_train,image_finger.reshape(1,-1)]) #1D
        # Y_train2=np.append(Y_train2,i)


        _,image_finger=preprocessing_new_2(img,debug=False)
        # features_train=np.vstack([features_train,image_finger.reshape(1,-1)]) #1D
        # Y_train2=np.append(Y_train2,i)



        # binary_hand=Get_Hand(img)
        # binary_hand=preprocessing_hagrass_eq_s(img)
        # binary_hand=preRGB(img)
        # binary_hand=preprocessing(img, gamma=True, close=True)
        # binary_hand=preprocessing2(img)
        
        # OCR,binary_hand=Cut_pre(img)
        # features_vector_train=OCR(features_vector_train,binary_hand,filename)
        # features_vector_train=np.append(features_vector_train,OCR)
        # Y_train=np.append(Y_train,i)
        # print(features_vector_train)
        # print(Y_train)

        # cv2.imwrite(path_of_the_directory_result+filename,image_finger)
        # break

    # break
    path_of_the_directory='../data_split_resize/women/train/'+str(i)+'/'
    path_of_the_directory_result='../outputs/preprocessing/women/train/'+str(i)+'/'
    isExist = os.path.exists(path_of_the_directory_result)
    if not isExist:
        os.makedirs(path_of_the_directory_result)
        print("The new directory is created!")
    ind=0
    for filename in os.listdir(path_of_the_directory):
        if(ind>max):
            break
        ind=ind+1
        img = cv2.imread(path_of_the_directory+str(filename))
        if img is None:
            continue

        # Skin Masks
        # binary_hand=preprocessing_new_1(img)

        # region_filling=binary_hand=preprocessing_new_2(img)

        # OCR,binary_hand=preprocessing_OCR(img)
        # features_vector_train=np.vstack([features_vector_train,OCR])
        # Y_train=np.append(Y_train,i)

        # OCR,hand_mask,image_finger=preprocessing_new_3(img)
        # features_train=np.vstack([features_train,image_finger.reshape(1,-1)]) #1D
        # Y_train2=np.append(Y_train2,i)


        _,image_finger=preprocessing_new_2(img,debug=False)
        # features_train=np.vstack([features_train,image_finger.reshape(1,-1)]) #1D
        # Y_train2=np.append(Y_train2,i)



        # binary_hand=Get_Hand(img)
        # binary_hand=preprocessing_hagrass_eq_s(img)
        # binary_hand=preRGB(img)
        # features_vector_train=OCR(features_vector_train,binary_hand,filename)
        # Y_train=np.append(Y_train,i)
        # binary_hand=preprocessing(img, gamma=True, close=True)
        # binary_hand=preprocessing2(img)


        # OCR,binary_hand=Cut_pre(img)
        # features_vector_train=OCR(features_vector_train,binary_hand,filename)
        # features_vector_train=np.append(features_vector_train,OCR)
        # Y_train=np.append(Y_train,i)
        # print(features_vector_train)
        # print(Y_train)
        
        # cv2.imwrite(path_of_the_directory_result+filename,image_finger)


# print(features_vector_train)
# print(Y_train)
# Out:
# 0
# shadow_removed 0.07300496101379395
# Gamma 0.0
# ycrcb_image 0.0019965171813964844
# Flip 0.002997875213623047
# Translate 0.0020046234130859375
# Cut Fingers 0.0019958019256591797
# shadow_removed 0.06199932098388672
# Gamma 0.0
# ycrcb_image 0.0019981861114501953
# Flip 0.0029990673065185547
# Translate 0.002007007598876953
# Cut Fingers 0.0010218620300292969
# shadow_removed 0.06496477127075195
# Gamma 0.0010018348693847656
# ycrcb_image 0.0019996166229248047
# Flip 0.0029993057250976562
# Translate 0.002000570297241211
# Cut Fingers 0.002000093460083008
# shadow_removed 0.06699872016906738
# Gamma 0.0
# ycrcb_image 0.0010044574737548828
# Flip 0.002998828887939453
# Translate 0.0009677410125732422
# Cut Fingers 0.002034425735473633
# shadow_removed 0.052965402603149414
# Gamma 0.0
# ycrcb_image 0.001999378204345703
# Flip 0.0029997825622558594
# Translate 0.004004716873168945
# Cut Fingers 0.004996776580810547
# shadow_removed 0.05698871612548828
# Gamma 0.0
# ycrcb_image 0.0010004043579101562
# Flip 0.0019991397857666016
# Translate 0.0040073394775390625
# Cut Fingers 0.004003763198852539
# 1
# shadow_removed 0.06799578666687012
# Gamma 0.0
# ycrcb_image 0.0020024776458740234
# Flip 0.0019991397857666016
# Translate 0.002002239227294922
# Cut Fingers 0.00099945068359375
# shadow_removed 0.06303596496582031
# Gamma 0.0
# ycrcb_image 0.0029611587524414062
# Flip 0.002999544143676758
# Translate 0.0020020008087158203
# Cut Fingers 0.0009987354278564453
# shadow_removed 0.06300091743469238
# Gamma 0.0009679794311523438
# ycrcb_image 0.0020236968994140625
# Flip 0.0019996166229248047
# Translate 0.0019676685333251953
# Cut Fingers 0.0010004043579101562
# shadow_removed 0.06300210952758789
# Gamma 0.0
# ycrcb_image 0.001997709274291992
# Flip 0.002000093460083008
# Translate 0.001967906951904297
# Cut Fingers 0.0010001659393310547
# shadow_removed 0.051999568939208984
# Gamma 0.0
# ycrcb_image 0.0009672641754150391
# Flip 0.001999378204345703
# Translate 0.005001544952392578
# Cut Fingers 0.003998994827270508
# shadow_removed 0.07104802131652832
# Gamma 0.0
# ycrcb_image 0.001993894577026367
# Flip 0.0030329227447509766
# Translate 0.0010066032409667969
# Cut Fingers 0.0019953250885009766
# 2
# shadow_removed 0.05396604537963867
# Gamma 0.001009225845336914
# ycrcb_image 0.0019915103912353516
# Flip 0.004995584487915039
# Translate 0.0020020008087158203
# Cut Fingers 0.0020017623901367188
# shadow_removed 0.06800031661987305
# Gamma 0.0
# ycrcb_image 0.002038240432739258
# Flip 0.001992940902709961
# Translate 0.001967191696166992
# Cut Fingers 0.003021717071533203
# shadow_removed 0.06100583076477051
# Gamma 0.0
# ycrcb_image 0.0009655952453613281
# Flip 0.0019996166229248047
# Translate 0.0019676685333251953
# Cut Fingers 0.002030611038208008
# shadow_removed 0.061010122299194336
# Gamma 0.000990152359008789
# ycrcb_image 0.00099945068359375
# Flip 0.003031492233276367
# Translate 0.0009698867797851562
# Cut Fingers 0.002031564712524414
# shadow_removed 0.05103349685668945
# Gamma 0.0
# ycrcb_image 0.0009682178497314453
# Flip 0.0019991397857666016
# Translate 0.002001523971557617
# Cut Fingers 0.00099945068359375
# shadow_removed 0.04900074005126953
# Gamma 0.001001119613647461
# ycrcb_image 0.001005411148071289
# Flip 0.0029921531677246094
# Translate 0.0010008811950683594
# Cut Fingers 0.001999378204345703
# 3
# shadow_removed 0.060013532638549805
# Gamma 0.0
# ycrcb_image 0.0009675025939941406
# Flip 0.002997875213623047
# Translate 0.0019676685333251953
# Cut Fingers 0.0010330677032470703
# shadow_removed 0.058004140853881836
# Gamma 0.000982522964477539
# ycrcb_image 0.0009801387786865234
# Flip 0.00299835205078125
# Translate 0.0020232200622558594
# Cut Fingers 0.0010123252868652344
# shadow_removed 0.05899977684020996
# Gamma 0.0
# ycrcb_image 0.001966714859008789
# Flip 0.00299835205078125
# Translate 0.0010046958923339844
# Cut Fingers 0.001997709274291992
# shadow_removed 0.05899810791015625
# Gamma 0.0009686946868896484
# ycrcb_image 0.0009992122650146484
# Flip 0.003031492233276367
# Translate 0.0009691715240478516
# Cut Fingers 0.0020308494567871094
# shadow_removed 0.04900050163269043
# Gamma 0.0
# ycrcb_image 0.0009980201721191406
# Flip 0.0019979476928710938
# Translate 0.0019991397857666016
# Cut Fingers 0.003001689910888672
# shadow_removed 0.059999704360961914
# Gamma 0.0
# ycrcb_image 0.002000093460083008
# Flip 0.003000497817993164
# Translate 0.0009984970092773438
# Cut Fingers 0.0010025501251220703
# 4
# shadow_removed 0.05999946594238281
# Gamma 0.001001119613647461
# ycrcb_image 0.0009968280792236328
# Flip 0.002999544143676758
# Translate 0.00099945068359375
# Cut Fingers 0.002002239227294922
# shadow_removed 0.06099987030029297
# Gamma 0.0010008811950683594
# ycrcb_image 0.000997304916381836
# Flip 0.002999544143676758
# Translate 0.0020008087158203125
# Cut Fingers 0.0020008087158203125
# shadow_removed 0.06000041961669922
# Gamma 0.0010328292846679688
# ycrcb_image 0.0009670257568359375
# Flip 0.0030324459075927734
# Translate 0.0009701251983642578
# Cut Fingers 0.0020394325256347656
# shadow_removed 0.05800199508666992
# Gamma 0.0
# ycrcb_image 0.0009653568267822266
# Flip 0.001965045928955078
# Translate 0.0019996166229248047
# Cut Fingers 0.002032041549682617
# shadow_removed 0.05599689483642578
# Gamma 0.0009746551513671875
# ycrcb_image 0.0009970664978027344
# Flip 0.002995014190673828
# Translate 0.003000974655151367
# Cut Fingers 0.002035856246948242
# shadow_removed 0.05703306198120117
# Gamma 0.0
# ycrcb_image 0.0019996166229248047
# Flip 0.0019998550415039062
# Translate 0.001968860626220703
# Cut Fingers 0.0019991397857666016
# 5
# shadow_removed 0.05703473091125488
# Gamma 0.0
# ycrcb_image 0.001964569091796875
# Flip 0.0019996166229248047
# Translate 0.0020008087158203125
# Cut Fingers 0.0010004043579101562
# shadow_removed 0.05503201484680176
# Gamma 0.0009770393371582031
# ycrcb_image 0.0009894371032714844
# Flip 0.003036022186279297
# Translate 0.001965045928955078
# Cut Fingers 0.006002187728881836
# shadow_removed 0.05297589302062988
# Gamma 0.0009984970092773438
# ycrcb_image 0.0019986629486083984
# Flip 0.0030002593994140625
# Translate 0.002006053924560547
# Cut Fingers 0.000993490219116211
# shadow_removed 0.0729990005493164
# Gamma 0.0
# ycrcb_image 0.0019948482513427734
# Flip 0.0030012130737304688
# Translate 0.0020003318786621094
# Cut Fingers 0.002022981643676758
# shadow_removed 0.08098816871643066
# Gamma 0.0
# ycrcb_image 0.0020008087158203125
# Flip 0.008068323135375977
# Translate 0.0049326419830322266
# Cut Fingers 0.002998828887939453
# shadow_removed 0.06899785995483398
# Gamma 0.0
# ycrcb_image 0.0010008811950683594
# Flip 0.0029973983764648438
# Translate 0.006004810333251953
# Cut Fingers 0.0019850730895996094
